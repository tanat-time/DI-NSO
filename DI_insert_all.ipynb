# %%
import pandas as pd
import json
import requests
## MAC
# df1 = pd.read_excel('/Users/admin/Documents/VScode/NSO/NSO-1/newdi.xlsx')
## WINDOW
# df1 = pd.read_excel('req_data.xlsx')
# # df = df1.loc[df1['ผู้ดำเนินการบันทึกคำร้องขอ']== 'คุณทาม']
# df = df1.loc[df1['ผู้รับผิดชอบ (กคร.)']== 'นางสาวณัฐฐิญา เรืองฤทธิ์']
# # df = df.dropna(subset=['ชื่อคำร้องขอ'])
# df

# %%
sheet_name = 'Dataset_DI_Project_25670905_time' # replace with your own sheet name
sheet_id = '1Dt2vVd81r8uz73a7PBRIFeucYzRosTWP' # replace with your sheet's ID
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
df = pd.read_csv(url)
# df = df1.loc[df1['ผู้ดำเนินการบันทึกคำร้องขอ']== 'คุณทาม']
# df = df.loc[df['ผู้รับผิดชอบ (กคร.)']== 'นางสาวณัฐฐิญา เรืองฤทธิ์']
# df = df.loc[df['ชื่อคำร้องขอ']== 'จำนวนเลขหมายโทรศัพท์ประจำที่และโทรศัพท์เคลื่อนที่จัดสรรสะสม']
df
# Out:
#     No (อ้างอิงภาคผนวก ข) งานงวดที่  Dinamic web        ผู้รับผิดชอบ (กคร.)  \
# 0                     599  งวดที่ 4        False  นางสาวธิดารัตน์ แน่นสิงห์
# 1                     601  งวดที่ 4        False  นางสาวธิดารัตน์ แน่นสิงห์
# 2                     602  งวดที่ 4        False  นางสาวธิดารัตน์ แน่นสิงห์
# 3                     603  งวดที่ 4        False  นางสาวธิดารัตน์ แน่นสิงห์
# 4                     605  งวดที่ 4        False  นางสาวธิดารัตน์ แน่นสิงห์
# 5                     606  งวดที่ 4        False  นางสาวธิดารัตน์ แน่นสิงห์
# 6                     607  งวดที่ 4        False  นางสาวธิดารัตน์ แน่นสิงห์
# 7                     668  งวดที่ 4        False  นางสาวธิดารัตน์ แน่นสิงห์
# 8                     689  งวดที่ 4        False  นางสาวธิดารัตน์ แน่นสิงห์
# 9                     691  งวดที่ 4        False  นางสาวธิดารัตน์ แน่นสิงห์
# 10                    692  งวดที่ 4        False  นางสาวธิดารัตน์ แน่นสิงห์
# 11                    694  งวดที่ 4        False  นางสาวธิดารัตน์ แน่นสิงห์
#
#                อีเมล  เบอร์ติดต่อ       ชื่อหน่วยงานของผู้ร้องขอ  \
# 0   tdarat@gmail.com  02-141-7405  ศูนย์สารสนเทศยุทธศาสตร์ภาครัฐ
# 1   tdarat@gmail.com  02-141-7405  ศูนย์สารสนเทศยุทธศาสตร์ภาครัฐ
# 2   tdarat@gmail.com  02-141-7405  ศูนย์สารสนเทศยุทธศาสตร์ภาครัฐ
# 3   tdarat@gmail.com  02-141-7405  ศูนย์สารสนเทศยุทธศาสตร์ภาครัฐ
# 4   tdarat@gmail.com  02-141-7405  ศูนย์สารสนเทศยุทธศาสตร์ภาครัฐ
# 5   tdarat@gmail.com  02-141-7405  ศูนย์สารสนเทศยุทธศาสตร์ภาครัฐ
# 6   tdarat@gmail.com  02-141-7405  ศูนย์สารสนเทศยุทธศาสตร์ภาครัฐ
# 7   tdarat@gmail.com  02-141-7405  ศูนย์สารสนเทศยุทธศาสตร์ภาครัฐ
# 8   tdarat@gmail.com  02-141-7405  ศูนย์สารสนเทศยุทธศาสตร์ภาครัฐ
# 9   tdarat@gmail.com  02-141-7405  ศูนย์สารสนเทศยุทธศาสตร์ภาครัฐ
# 10  tdarat@gmail.com  02-141-7405  ศูนย์สารสนเทศยุทธศาสตร์ภาครัฐ
# 11  tdarat@gmail.com  02-141-7405  ศูนย์สารสนเทศยุทธศาสตร์ภาครัฐ
#
#                   ชื่อคำร้องขอ                  DF  \
# 0   ข้อหาในคดีที่เข้าศาลแรงงาน  DF_02DI_CASE_COURT
# 1   ข้อหาในคดีที่เข้าศาลแรงงาน  DF_02DI_CASE_COURT
# 2   ข้อหาในคดีที่เข้าศาลแรงงาน  DF_02DI_CASE_COURT
# 3   ข้อหาในคดีที่เข้าศาลแรงงาน  DF_02DI_CASE_COURT
# 4   ข้อหาในคดีที่เข้าศาลแรงงาน  DF_02DI_CASE_COURT
# 5   ข้อหาในคดีที่เข้าศาลแรงงาน  DF_02DI_CASE_COURT
# 6   ข้อหาในคดีที่เข้าศาลแรงงาน  DF_02DI_CASE_COURT
# 7   ข้อหาในคดีที่เข้าศาลแรงงาน  DF_02DI_CASE_COURT
# 8   ข้อหาในคดีที่เข้าศาลแรงงาน  DF_02DI_CASE_COURT
# 9   ข้อหาในคดีที่เข้าศาลแรงงาน  DF_02DI_CASE_COURT
# 10  ข้อหาในคดีที่เข้าศาลแรงงาน  DF_02DI_CASE_COURT
# 11  ข้อหาในคดีที่เข้าศาลแรงงาน  DF_02DI_CASE_COURT
#
#            ชื่อชุดข้อมูลจริง ตาม fusion  ... ปีสิ้นสุด  \
# 0   ชุดข้อมูลข้อหาในคดีที่เข้าศาลแรงงาน  ...      2565
# 1   ชุดข้อมูลข้อหาในคดีที่เข้าศาลแรงงาน  ...      2565
# 2   ชุดข้อมูลข้อหาในคดีที่เข้าศาลแรงงาน  ...      2565
# 3   ชุดข้อมูลข้อหาในคดีที่เข้าศาลแรงงาน  ...      2565
# 4   ชุดข้อมูลข้อหาในคดีที่เข้าศาลแรงงาน  ...      2565
# 5   ชุดข้อมูลข้อหาในคดีที่เข้าศาลแรงงาน  ...      2565
# 6   ชุดข้อมูลข้อหาในคดีที่เข้าศาลแรงงาน  ...      2565
# 7   ชุดข้อมูลข้อหาในคดีที่เข้าศาลแรงงาน  ...      2565
# 8   ชุดข้อมูลข้อหาในคดีที่เข้าศาลแรงงาน  ...      2565
# 9   ชุดข้อมูลข้อหาในคดีที่เข้าศาลแรงงาน  ...      2565
# 10  ชุดข้อมูลข้อหาในคดีที่เข้าศาลแรงงาน  ...      2565
# 11  ชุดข้อมูลข้อหาในคดีที่เข้าศาลแรงงาน  ...      2565
#
#    ความเร่งด่วนการนำมาใช้งาน       สาขา        สถิติ วันที่และเวลาร้องขอ  \
# 0                     15 วัน  02 แรงงาน  สถิติทั่วไป                 NaN
# 1                     15 วัน  02 แรงงาน  สถิติทั่วไป                 NaN
# 2                     15 วัน  02 แรงงาน  สถิติทั่วไป                 NaN
# 3                     15 วัน  02 แรงงาน  สถิติทั่วไป                 NaN
# 4                     15 วัน  02 แรงงาน  สถิติทั่วไป                 NaN
# 5                     15 วัน  02 แรงงาน  สถิติทั่วไป                 NaN
# 6                     15 วัน  02 แรงงาน  สถิติทั่วไป                 NaN
# 7                     15 วัน  02 แรงงาน  สถิติทั่วไป                 NaN
# 8                     15 วัน  02 แรงงาน  สถิติทั่วไป                 NaN
# 9                     15 วัน  02 แรงงาน  สถิติทั่วไป                 NaN
# 10                    15 วัน  02 แรงงาน  สถิติทั่วไป                 NaN
# 11                    15 วัน  02 แรงงาน  สถิติทั่วไป                 NaN
#
#    สถานะการขึ้นคำร้องขอ                       สถานะการขึ้นคำร้องขอ.1  \
# 0                   NaN                  บันทึกคำร้องขอแล้ว โดย กคร.
# 1                   NaN                  บันทึกคำร้องขอแล้ว โดย กคร.
# 2                   NaN                  บันทึกคำร้องขอแล้ว โดย กคร.
# 3                   NaN                  บันทึกคำร้องขอแล้ว โดย กคร.
# 4                   NaN                  บันทึกคำร้องขอแล้ว โดย กคร.
# 5                   NaN                  บันทึกคำร้องขอแล้ว โดย กคร.
# 6                   NaN                  บันทึกคำร้องขอแล้ว โดย กคร.
# 7                   NaN  อยู่ระหว่างดำเนินการบันทึกคำร้องขอ โดย MFEC
# 8                   NaN  อยู่ระหว่างดำเนินการบันทึกคำร้องขอ โดย กคร.
# 9                   NaN  อยู่ระหว่างดำเนินการบันทึกคำร้องขอ โดย กคร.
# 10                  NaN  อยู่ระหว่างดำเนินการบันทึกคำร้องขอ โดย กคร.
# 11                  NaN  อยู่ระหว่างดำเนินการบันทึกคำร้องขอ โดย กคร.
#
#    ผู้ดำเนินการบันทึกคำร้องขอ กลุ่ม Unnamed: 38
# 0           คุณโค้ก / พี่แก้ว  กคร.         NaN
# 1           คุณโค้ก / พี่แก้ว  กคร.         NaN
# 2           คุณโค้ก / พี่แก้ว  กคร.         NaN
# 3           คุณโค้ก / พี่แก้ว  กคร.         NaN
# 4           คุณโค้ก / พี่แก้ว  กคร.         NaN
# 5           คุณโค้ก / พี่แก้ว  กคร.         NaN
# 6           คุณโค้ก / พี่แก้ว  กคร.         NaN
# 7           คุณโค้ก / พี่แก้ว  กคร.         NaN
# 8           คุณโค้ก / พี่แก้ว  กคร.         NaN
# 9           คุณโค้ก / พี่แก้ว  กคร.         NaN
# 10          คุณโค้ก / พี่แก้ว  กคร.         NaN
# 11          คุณโค้ก / พี่แก้ว  กคร.         NaN
#
# [12 rows x 39 columns]

# %%
df['ระบุหน้า']
# Out:
# 0    -
# Name: ระบุหน้า, dtype: object

# %%
df.columns
# Out:
# Index(['No (อ้างอิงภาคผนวก ข)', 'งานงวดที่', 'Dinamic web',
#        'ผู้รับผิดชอบ (กคร.)', 'อีเมล', 'เบอร์ติดต่อ',
#        'ชื่อหน่วยงานของผู้ร้องขอ', 'ชื่อคำร้องขอ', 'DF',
#        'ชื่อชุดข้อมูลจริง ตาม fusion', 'การคำนวณค่าสถิติ', 'ชื่อรายการสถิติ',
#        'กระทรวง', 'กรม',
#        'หน่วยงานนี้เป็นผู้ผลิตข้อมูลสถิติ (Data Owner) ใช่หรือไม่',
#        'ชื่อตารางสถิติแสดงจากแหล่งข้อมูลต้นทาง', 'URL ของแหล่งข้อมูลต้นทาง',
#        'ลักษณะของตารางสถิติ', 'รูปแบบการใช้บริการของไฟล์ต้นทาง',
#        'รูปแบบของตารางสถิติจาก URL แหล่งข้อมูลต้นทาง', 'ระบุหน้า',
#        'รูปภาพตารางสถิติแหล่งข้อมูลต้นทาง', 'วัตถุประสงค์การใช้งาน',
#        'ความถี่ในการเผยแพร่ข้อมูล', 'การจัดจำแนก',
#        'พื้นที่ (จากไฟล์ทะเบียน 2281 รายการ)', 'พื้นที่\n(ใส่ในคำร้อง)',
#        'นอกเหนือจาก ทั่วราช ภาค จังหวัด เขตการปกครอง อำเภอ ตำบล', 'ปีเริ่มต้น',
#        'ปีสิ้นสุด', 'ความเร่งด่วนการนำมาใช้งาน', 'สาขา', 'สถิติ',
#        'วันที่และเวลาร้องขอ', 'สถานะการขึ้นคำร้องขอ', 'สถานะการขึ้นคำร้องขอ.1',
#        'ผู้ดำเนินการบันทึกคำร้องขอ', 'กลุ่ม', 'Unnamed: 38'],
#       dtype='object')

# %%
req_name = df['ชื่อคำร้องขอ'].unique()
len(req_name)
# Out:
# 13

# %%
import pymongo
import pandas as pd

myclient = pymongo.MongoClient("mongodb://admin:password@docker.greencluster.co.th:7005/")
mydb = myclient["NSO_DI"]
mycol = mydb["MT_DROPDOWNS"]

myquery = {'ID' : '1'}
mydoc = mycol.find(myquery)
for x in mydoc:
    y = x['Options']
    

def getdata_mongo(number):
    myquery = {'ID' : number}
    mydoc = mycol.find(myquery)
    for x in mydoc:
        y = x['Options']
    df = pd.DataFrame(columns=('value','text'))
    i =0 
    while i<len(y):
        df.loc[i]=[y[i]['value'],y[i]['text']]
        i=i+1
    return df

statistics_calculation = getdata_mongo('0')
source_table_style = getdata_mongo('1')
source_table_type = getdata_mongo('2')
source_table_type_from_url = getdata_mongo('3')
urgency = getdata_mongo('4')
area = getdata_mongo('5')
statistics = getdata_mongo('6')
statistics_requset_status = getdata_mongo('7')
nso_department = getdata_mongo('8')
inspection_results = getdata_mongo('9')
statistics_branch = getdata_mongo('10')
frequency = getdata_mongo('11')
group_1_checklist = getdata_mongo('12')
group_2_checklist = getdata_mongo('13')

# %%
def MIN_ID(text):
    myclient = pymongo.MongoClient("mongodb://admin:password@docker.greencluster.co.th:7005/")
    mydb = myclient["NSO_UM"]
    mycol = mydb["US_MT_MINISTRIES"]
    mydoc = mycol.find()
    for x in mydoc:
        if x['MinistryName'] == text :
            return (x['ID']) 

def DEP_ID(text):
    myclient = pymongo.MongoClient("mongodb://admin:password@docker.greencluster.co.th:7005/")
    mydb = myclient["NSO_UM"]
    mycol = mydb["US_MT_DEPARTMENTS"]
    mydoc = mycol.find()
    for x in mydoc:
        if x['DepartmentName'] == text :
            return (x['ID']) 

def data_onwer(text):
    if text == 'ใช่':
        return True
    else :
        return False

def areatype(text):
    if  'ทั่วราชอาณาจักร' in text:
        return '1'
    elif text == 'ภาค':
        return '2'
    elif text == 'จังหวัด':
        return '3'
    elif text == 'เขตการปกครอง':
        return '4'
    elif text == 'อำเภอ':
        return '5'
    elif text == 'ตำบล':
        return '6'
    elif text == 'อื่นๆ':
        return '7'
    else:
        return '8'

# %% [markdown]
# Validate

# %%
# break_list = ['จำนวนคนจน และสัดส่วนคนจนจำแนกตามขนาดครัวเรือน','สถิติส่งเสริมการลงทุน','สถาบันยานยนต์','โรงงานอุตสาหกรรมที่เลิกประกอบกิจการ','การจ้างงาน และรายได้ของวิสาหกิจขนาดกลางและขนาดย่อม','นักท่องเที่ยวระหว่างประเทศที่เดินทางเข้าประเทศไทย','การสะสมทุนถาวรขั้นต้นตามสถาบันภาครัฐและเอกชน','รายจ่ายเกี่ยวกับผลิตภัณฑ์มวลรวมภายในประเทศ การวัดปริมาณห่วงโซ่','สถิติสำหรับจัดทำดัชนีอุตสาหกรรม']
# break_list = ['จำนวนคนจน และสัดส่วนคนจนจำแนกตามขนาดครัวเรือน','สถาบันยานยนต์','การจ้างงาน และรายได้ของวิสาหกิจขนาดกลางและขนาดย่อม','สถิติสำหรับจัดทำดัชนีอุตสาหกรรม','การสะสมทุนถาวรขั้นต้นตามสถาบันภาครัฐและเอกชน']
# break_list = ['รายงานต้นทุนผลผลิต']
sheet_name = 'Dataset_DI_Project_25670905_time' # replace with your own sheet name
sheet_id = '1Dt2vVd81r8uz73a7PBRIFeucYzRosTWP' # replace with your sheet's ID
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
df = pd.read_csv(url)
break_list=[]
req_name = df['ชื่อคำร้องขอ'].unique()
count = 0 
row =0
for x in req_name:
    print('ชื่อคำร้อง :',x)
    if x in break_list:
        continue
    j=1
    df_req = df.loc[df['ชื่อคำร้องขอ']== x]
    table_name = df_req['ชื่อตารางสถิติแสดงจากแหล่งข้อมูลต้นทาง'].unique()
    table_len = len(table_name)
    temp_table = []
    for y in table_name:
        print(' ชื่อตารางสถิติ :',y)
        df_table = df_req.loc[df_req['ชื่อตารางสถิติแสดงจากแหล่งข้อมูลต้นทาง']== y]
        df_table = df_table.reset_index(drop=True)
        static_name = df_table['ชื่อรายการสถิติ'].unique()
        temp_static =[]
        i=1
        for z in static_name:
            print(z)
            df_static = df_table.loc[df_table['ชื่อรายการสถิติ']== z]
            df_static = df_static.reset_index(drop=True)
            # try:
            print(df_static['No (อ้างอิงภาคผนวก ข)'].values[0])
            frequency_array = []
            area_array = []
            frequency_split = df_static['ความถี่ในการเผยแพร่ข้อมูล'].values[0]
            frequency_split = frequency_split.split('\n')
            for a in frequency_split:
                if a == '':
                    continue
                else:
                    frequency_array.append(frequency['value'].loc[frequency['text']== a[2:].rstrip()].values[0])
            aresplit =df_static['พื้นที่\n(ใส่ในคำร้อง)'].values[0]
            aresplit = aresplit.split('\n')
            dimension = []
            for b in aresplit:
                area_array.append(areatype(str(b[2:])))
            AreaOther = ""
            if '8' in area_array:
                area_array.remove('8')
            if '7' in area_array:
                AreaOther = df_static['นอกเหนือจาก ทั่วราช ภาค จังหวัด เขตการปกครอง อำเภอ ตำบล'].values[0]
                AreaOther = AreaOther[2:]
                # if type(AreaOther) == float:
                #      AreaOther = ""
                # else:
                #     AreaOther = AreaOther[2:]
            dimensionslit = df_table['การจัดจำแนก'].values[0]
            dimensionslit = dimensionslit.split('\n')
            dimensionarray = []
            if '- ไม่มีการจัดจำแนก' in dimensionslit:
                dimensionarray = []
            else:
                k=1
                for c in dimensionslit:
                    if c == '':
                        continue
                    else:
                        dimension = {
                        "ClassifiedDimensionID": k,
                        "Value": c[2:],
                        "value": None
                    }
                    k=k+1
                    dimensionarray.append(dimension)
            body_static = {
                        "ListID": i,
                        "StatisticsName": z,
                        "StatisticsCalculation": (statistics_calculation['value'].loc[statistics_calculation['text']==df_static['การคำนวณค่าสถิติ'][0]].values[0]),
                        "Purpose": df_static['วัตถุประสงค์การใช้งาน'][0],
                        "Frequency": frequency_array,
                        "Urgency": urgency['value'].loc[urgency['text']== df_static['ความเร่งด่วนการนำมาใช้งาน'][0]].values[0],
                        "Area": area_array,
                        "AreaOther": AreaOther[2:],
                        "YearStart": df_static['ปีเริ่มต้น'][0],
                        "YearEnd": df_static['ปีสิ้นสุด'][0],
                        "ClassifiedDimensions": dimensionarray,
                        "Statistics": statistics['value'].loc[statistics['text']== df_static['สถิติ'][0]].values[0],
                        "StatisticsBranch": str(int(df_static['สาขา'][0][:2]))
                    }
            temp_static.append(body_static)
            # except Exception as error:
                # handle the exception
            # print(df_static['No (อ้างอิงภาคผนวก ข)'])
            # print("An exception occurred:", error)
            i=i+1
        # break
        page = ""
        sheet = ""
        if df_table['รูปแบบของตารางสถิติจาก URL แหล่งข้อมูลต้นทาง'].values[0] == 'XLS' or df_table['รูปแบบของตารางสถิติจาก URL แหล่งข้อมูลต้นทาง'].values[0] == 'XLSX' or df_table['รูปแบบของตารางสถิติจาก URL แหล่งข้อมูลต้นทาง'].values[0] == 'xls' :
            df_table['รูปแบบของตารางสถิติจาก URL แหล่งข้อมูลต้นทาง'].values[0] = 'EXCEL'
        if df_table['รูปแบบของตารางสถิติจาก URL แหล่งข้อมูลต้นทาง'].values[0] == 'PDF':
            page = df_table['ระบุหน้า'].values[0]
        elif df_table['รูปแบบของตารางสถิติจาก URL แหล่งข้อมูลต้นทาง'].values[0] == 'EXCEL':
            sheet = df_table['ระบุหน้า'].values[0]
            sheet = str(sheet).replace('\n', ' ')
        body_table = {
            "TableID": j,
            "SourceTableName": y,
            "SourceTableUrl": df_table['URL ของแหล่งข้อมูลต้นทาง'].values[0],
            "SourceMinistry": MIN_ID(df_table['กระทรวง'].values[0]),
            "SourceDepartment": DEP_ID(df_table['กรม'].values[0]),
            "SourceDataOwner": data_onwer(df_table['หน่วยงานนี้เป็นผู้ผลิตข้อมูลสถิติ (Data Owner) ใช่หรือไม่'].values[0]),
            "SourceTableStyle": source_table_style['value'].loc[source_table_style['text']== df_table['ลักษณะของตารางสถิติ'][0]].values[0],
            "SourceTableType": source_table_type['value'].loc[source_table_type['text']== df_table['รูปแบบการใช้บริการของไฟล์ต้นทาง'][0]].values[0],
            "SourceTableTypeFromUrl": source_table_type_from_url['value'].loc[source_table_type_from_url['text'] == df_table['รูปแบบของตารางสถิติจาก URL แหล่งข้อมูลต้นทาง'].values[0]].values[0],
            "SourceTableTypeFromUrlPdfPageNo": page,
            "SourceTableTypeFromUrlExcelSheet": sheet,
            "SourceTableFiles": [],
            "StatisticsList": temp_static
            }
        temp_table.append(body_table)
        j=j+1
    #print(table_len)
    count = count + len(df_req)
    ##print(row,"ชื่อคำร้อง :",x,"คำร้อง :",len(df_req),"จำนวนตาราง :",table_len)
    # if row == 0:
    #     break
    row = row+1
    req_data = { "NsoDepartment": nso_department['value'].loc[nso_department['text']== df_req['ชื่อหน่วยงานของผู้ร้องขอ'].values[0]].values[0],
    "StatisticsName": df_req['ชื่อคำร้องขอ'].values[0],
    "StatisticsTable": temp_table
    }
    # try:
    #     url = "https://diusam-api.nso.go.th/api/v1/Authentication/Login/LoginByEmail"
    #     headers = {
    #         "accept": "application/json",
    #         "Content-Type": "application/json"
    #     }
    #     data = {
    #     "email": "natti_ya@hotmail.com",
    #     "password": "018ff15906",
    #     "mastSystemKey": "SYS1"
    #     }

    #     response = requests.post(url, headers=headers, json=data)

    #     # print(response.status_code)
    #     # print(response.json())
    #     token = response.json()['ACCESS_TOKEN']
    #     # print(token)


    #     url = "https://di-api.nso.go.th/api/v1/StatisticsRequest/Request/Submit"

    #     headers = {
    #         "accept": "*/*",
    #         "UserAuthenticatedToken": token,
    #         "Content-Type": "application/json"
    #     }


    #     str_req_data = str(req_data).replace("'", '"')
    #     json_req_data = str_req_data.replace("True", "true")
    #     json_req_data = json_req_data.replace("None", "null")
    #     try:
    #         data_json = json.loads(json_req_data)
    #         # print(data_json)
    #     except json.JSONDecodeError as e:
    #         print(f"JSONDecodeError: {e.msg} at line {e.lineno} column {e.colno} (char {e.pos})")
    #     response = requests.post(url, headers=headers, json=data_json)
    #     print('success ชื่อคำร้อง :',x)
    # except Exception as error:
    #     print('error ชื่อคำร้อง :',x)
    #     print("An exception occurred:", error)
        
print("final count :",count)
print("final row :",row)
# Out:
# ชื่อคำร้อง : ผลิตภาพการผลิตของภาคอุตสาหกรรม
#  ชื่อตารางสถิติ : สถิติผลิตภาพและผลประกอบการอุตสาหกรรม
# ผลิตภาพการผลิตของภาคอุตสาหกรรม
# 2260
# final count : 1
# final row : 1

# %%
DEP_ID('สำนักแผนงานและงบประมาณ')
# Out:
# 'DEP239'

# %%
req_data
# Out:
# {'NsoDepartment': '9',
#  'StatisticsName': 'ผลิตภาพการผลิตของภาคอุตสาหกรรม',
#  'StatisticsTable': [{'TableID': 1,
#    'SourceTableName': 'สถิติผลิตภาพและผลประกอบการอุตสาหกรรม',
#    'SourceTableUrl': 'https://www.oie.go.th/assets/portals/1/fileups/2/files/TFP/DataSet_2022_32_01_The%20Growth%20Accounting%20of%20the%20Manufacturing%20Industry_TH.csv',
#    'SourceMinistry': 'MIN18',
#    'SourceDepartment': 'DEP180',
#    'SourceDataOwner': True,
#    'SourceTableStyle': '2',
#    'SourceTableType': '1',
#    'SourceTableTypeFromUrl': '5',
#    'SourceTableTypeFromUrlPdfPageNo': '',
#    'SourceTableTypeFromUrlExcelSheet': '',
#    'SourceTableFiles': [],
#    'StatisticsList': [{'ListID': 1,
#      'StatisticsName': 'ผลิตภาพการผลิตของภาคอุตสาหกรรม',
#      'StatisticsCalculation': '1',
#      'Purpose': 'เป็นชุดข้อมูลที่ใช้ในโครงการ DI',
#      'Frequency': ['1'],
#      'Urgency': '2',
#      'Area': ['1'],
#      'AreaOther': '',
#      'YearStart': 2561,
#      'YearEnd': 2563,
#      'ClassifiedDimensions': [{'ClassifiedDimensionID': 1,
#        'Value': 'สาขาการผลิต',
#        'value': None}],
#      'Statistics': '2',
#      'StatisticsBranch': '12'}]}]}

# %% [markdown]
# Insert to DI

# %%
# break_list = ['จำนวนคนจน และสัดส่วนคนจนจำแนกตามขนาดครัวเรือน','สถิติส่งเสริมการลงทุน','สถาบันยานยนต์','โรงงานอุตสาหกรรมที่เลิกประกอบกิจการ','การจ้างงาน และรายได้ของวิสาหกิจขนาดกลางและขนาดย่อม','นักท่องเที่ยวระหว่างประเทศที่เดินทางเข้าประเทศไทย','การสะสมทุนถาวรขั้นต้นตามสถาบันภาครัฐและเอกชน','รายจ่ายเกี่ยวกับผลิตภัณฑ์มวลรวมภายในประเทศ การวัดปริมาณห่วงโซ่','สถิติสำหรับจัดทำดัชนีอุตสาหกรรม']
# break_list = ['รายงานต้นทุนผลผลิต']
# break_list = ['จำนวนคนจน และสัดส่วนคนจนจำแนกตามขนาดครัวเรือน','สถาบันยานยนต์','การจ้างงาน และรายได้ของวิสาหกิจขนาดกลางและขนาดย่อม','สถิติสำหรับจัดทำดัชนีอุตสาหกรรม','การสะสมทุนถาวรขั้นต้นตามสถาบันภาครัฐและเอกชน']
break_list =[]
# break_list=['ผู้ต้องขังที่ได้รับการปล่อยตัวและกลับมากระทำผิดอีกครั้ง']
req_name = df['ชื่อคำร้องขอ'].unique()
count = 0 
row =0
for x in req_name:
    # print('ชื่อคำร้อง :',x)
    if x in break_list:
        continue
    j=1
    df_req = df.loc[df['ชื่อคำร้องขอ']== x]
    table_name = df_req['ชื่อตารางสถิติแสดงจากแหล่งข้อมูลต้นทาง'].unique()
    table_len = len(table_name)
    temp_table = []
    for y in table_name:
        # print(' ชื่อตารางสถิติ :',y)
        df_table = df_req.loc[df_req['ชื่อตารางสถิติแสดงจากแหล่งข้อมูลต้นทาง']== y]
        df_table = df_table.reset_index(drop=True)
        static_name = df_table['ชื่อรายการสถิติ'].unique()
        temp_static =[]
        i=1
        for z in static_name:
            # print(z)
            df_static = df_table.loc[df_table['ชื่อรายการสถิติ']== z]
            df_static = df_static.reset_index(drop=True)
            # try:
            # print(df_static['No (อ้างอิงภาคผนวก ข)'].values[0])
            frequency_array = []
            area_array = []
            frequency_split = df_static['ความถี่ในการเผยแพร่ข้อมูล'].values[0]
            frequency_split = frequency_split.split('\n')
            for a in frequency_split:
                if a == '':
                    continue
                else:
                    frequency_array.append(frequency['value'].loc[frequency['text']== a[2:].rstrip()].values[0])
            aresplit =df_static['พื้นที่\n(ใส่ในคำร้อง)'].values[0]
            aresplit = aresplit.split('\n')
            dimension = []
            for b in aresplit:
                area_array.append(areatype(str(b[2:])))
            AreaOther = ""
            if '8' in area_array:
                area_array.remove('8')
            if '7' in area_array:
                AreaOther = df_static['นอกเหนือจาก ทั่วราช ภาค จังหวัด เขตการปกครอง อำเภอ ตำบล'].values[0]
                AreaOther = AreaOther[2:]
                # if type(AreaOther) == float:
                #      AreaOther = ""
                # else:
                #     AreaOther = AreaOther[2:]
            dimensionslit = df_table['การจัดจำแนก'].values[0]
            dimensionslit = dimensionslit.split('\n')
            dimensionarray = []
            if '- ไม่มีการจัดจำแนก' in dimensionslit:
                dimensionarray = []
            else:
                k=1
                for c in dimensionslit:
                    if c == '':
                        continue
                    else:
                        dimension = {
                        "ClassifiedDimensionID": k,
                        "Value": c[2:],
                        "value": None
                    }
                    k=k+1
                    dimensionarray.append(dimension)
            body_static = {
                        "ListID": i,
                        "StatisticsName": z,
                        "StatisticsCalculation": (statistics_calculation['value'].loc[statistics_calculation['text']==df_static['การคำนวณค่าสถิติ'][0]].values[0]),
                        "Purpose": df_static['วัตถุประสงค์การใช้งาน'][0],
                        "Frequency": frequency_array,
                        "Urgency": urgency['value'].loc[urgency['text']== df_static['ความเร่งด่วนการนำมาใช้งาน'][0]].values[0],
                        "Area": area_array,
                        "AreaOther": AreaOther[2:],
                        "YearStart": df_static['ปีเริ่มต้น'][0],
                        "YearEnd": df_static['ปีสิ้นสุด'][0],
                        "ClassifiedDimensions": dimensionarray,
                        "Statistics": statistics['value'].loc[statistics['text']== df_static['สถิติ'][0]].values[0],
                        "StatisticsBranch": str(int(df_static['สาขา'][0][:2]))
                    }
            temp_static.append(body_static)
            # except Exception as error:
                # handle the exception
            # print(df_static['No (อ้างอิงภาคผนวก ข)'])
            # print("An exception occurred:", error)
            i=i+1
        # break
        page = ""
        sheet = ""
        if df_table['รูปแบบของตารางสถิติจาก URL แหล่งข้อมูลต้นทาง'].values[0] == 'XLS' or df_table['รูปแบบของตารางสถิติจาก URL แหล่งข้อมูลต้นทาง'].values[0] == 'XLSX' or df_table['รูปแบบของตารางสถิติจาก URL แหล่งข้อมูลต้นทาง'].values[0] == 'xls':
            df_table['รูปแบบของตารางสถิติจาก URL แหล่งข้อมูลต้นทาง'].values[0] = 'EXCEL'
        if df_table['รูปแบบของตารางสถิติจาก URL แหล่งข้อมูลต้นทาง'].values[0] == 'PDF':
            page = df_table['ระบุหน้า'].values[0]
        elif df_table['รูปแบบของตารางสถิติจาก URL แหล่งข้อมูลต้นทาง'].values[0] == 'EXCEL':
            sheet = df_table['ระบุหน้า'].values[0]
            sheet = str(sheet).replace('\n', ' ')
        body_table = {
            "TableID": j,
            "SourceTableName": y,
            "SourceTableUrl": df_table['URL ของแหล่งข้อมูลต้นทาง'].values[0],
            "SourceMinistry": MIN_ID(df_table['กระทรวง'].values[0]),
            "SourceDepartment": DEP_ID(df_table['กรม'].values[0]),
            "SourceDataOwner": data_onwer(df_table['หน่วยงานนี้เป็นผู้ผลิตข้อมูลสถิติ (Data Owner) ใช่หรือไม่'].values[0]),
            "SourceTableStyle": source_table_style['value'].loc[source_table_style['text']== df_table['ลักษณะของตารางสถิติ'][0]].values[0],
            "SourceTableType": source_table_type['value'].loc[source_table_type['text']== df_table['รูปแบบการใช้บริการของไฟล์ต้นทาง'][0]].values[0],
            "SourceTableTypeFromUrl": source_table_type_from_url['value'].loc[source_table_type_from_url['text'] == df_table['รูปแบบของตารางสถิติจาก URL แหล่งข้อมูลต้นทาง'].values[0]].values[0],
            "SourceTableTypeFromUrlPdfPageNo": page,
            "SourceTableTypeFromUrlExcelSheet": sheet,
            "SourceTableFiles": [],
            "StatisticsList": temp_static
            }
        temp_table.append(body_table)
        j=j+1
    #print(table_len)
    count = count + len(df_req)
    ##print(row,"ชื่อคำร้อง :",x,"คำร้อง :",len(df_req),"จำนวนตาราง :",table_len)
    # if row == 0:
    #     break
    row = row+1
    req_data = { "NsoDepartment": nso_department['value'].loc[nso_department['text']== df_req['ชื่อหน่วยงานของผู้ร้องขอ'].values[0]].values[0],
    "StatisticsName": df_req['ชื่อคำร้องขอ'].values[0],
    "StatisticsTable": temp_table
    }
    try:
        url = "https://diusam-api.nso.go.th/api/v1/Authentication/Login/LoginByEmail"
        headers = {
            "accept": "application/json",
            "Content-Type": "application/json"
        }
        data = {
        "email": "natti_ya@hotmail.com",
        "password": "018ff15906",
        "mastSystemKey": "SYS1"
        }

        response = requests.post(url, headers=headers, json=data)

        # print(response.status_code)
        # print(response.json())
        token = response.json()['ACCESS_TOKEN']
        # print(token)


        url = "https://di-api.nso.go.th/api/v1/StatisticsRequest/Request/Submit"

        headers = {
            "accept": "*/*",
            "UserAuthenticatedToken": token,
            "Content-Type": "application/json"
        }


        str_req_data = str(req_data).replace("'", '"')
        json_req_data = str_req_data.replace("True", "true")
        json_req_data = json_req_data.replace("None", "null")
        try:
            data_json = json.loads(json_req_data)
            # print(data_json)
        except json.JSONDecodeError as e:
            print(f"JSONDecodeError: {e.msg} at line {e.lineno} column {e.colno} (char {e.pos})")
        response = requests.post(url, headers=headers, json=data_json)
        print('success ชื่อคำร้อง :',x)
    except Exception as error:
        print('error ชื่อคำร้อง :',x)
        print("An exception occurred:", error)
        
print("final count :",count)
print("final row :",row)
# Out:
# success ชื่อคำร้อง : ผลิตภาพการผลิตของภาคอุตสาหกรรม
# final count : 1
# final row : 1

# %%
json_req_data
# Out:
# '{"NsoDepartment": "9", "StatisticsName": "สถาบันยานยนต์", "StatisticsTable": [{"TableID": 1, "SourceTableName": "สถิติปริมาณการผลิตรถจักรยานยนต์ในประเทศ", "SourceTableUrl": "https://data.thaiauto.or.th/auto/motorcycle-stat/stat-motorcycle-production-volumn/stat-motorcycle-production-volumn-thai.html", "SourceMinistry": "MIN18", "SourceDepartment": "DEP242", "SourceDataOwner": true, "SourceTableStyle": "1", "SourceTableType": "2", "SourceTableTypeFromUrl": "2", "SourceTableTypeFromUrlPdfPageNo": "", "SourceTableTypeFromUrlExcelSheet": "-", "SourceTableFiles": [], "StatisticsList": [{"ListID": 1, "StatisticsName": "การผลิตรถจักรยานยนต์ในประเทศ", "StatisticsCalculation": "1", "Purpose": "เป็นชุดข้อมูลที่ใช้ในโครงการ DI", "Frequency": ["1"], "Urgency": "2", "Area": ["1"], "AreaOther": "", "YearStart": 2555, "YearEnd": 2567, "ClassifiedDimensions": [], "Statistics": "2", "StatisticsBranch": "12"}, {"ListID": 2, "StatisticsName": "การผลิตรถจักรยานยนต์ในประเทศขนาดน้อยกว่าหรือเท่ากับ 150 CC", "StatisticsCalculation": "1", "Purpose": "เป็นชุดข้อมูลที่ใช้ในโครงการ DI", "Frequency": ["1"], "Urgency": "2", "Area": ["1"], "AreaOther": "", "YearStart": 2555, "YearEnd": 2567, "ClassifiedDimensions": [], "Statistics": "2", "StatisticsBranch": "12"}, {"ListID": 3, "StatisticsName": "การผลิตรถจักรยานยนต์ในประเทศขนาด 150-399 CC", "StatisticsCalculation": "1", "Purpose": "เป็นชุดข้อมูลที่ใช้ในโครงการ DI", "Frequency": ["1"], "Urgency": "2", "Area": ["1"], "AreaOther": "", "YearStart": 2555, "YearEnd": 2567, "ClassifiedDimensions": [], "Statistics": "2", "StatisticsBranch": "12"}, {"ListID": 4, "StatisticsName": "การผลิตรถจักรยานยนต์ในประเทศขนาดมากกว่าหรือเท่ากับ 400 CC", "StatisticsCalculation": "1", "Purpose": "เป็นชุดข้อมูลที่ใช้ในโครงการ DI", "Frequency": ["1"], "Urgency": "2", "Area": ["1"], "AreaOther": "", "YearStart": 2555, "YearEnd": 2567, "ClassifiedDimensions": [], "Statistics": "2", "StatisticsBranch": "12"}, {"ListID": 5, "StatisticsName": "ปริมาณการส่งออกรถจักรยานยนต์ที่ผลิตสำเร็จแล้ว", "StatisticsCalculation": "7", "Purpose": "เป็นชุดข้อมูลที่ใช้ในโครงการ DI", "Frequency": ["1", "3"], "Urgency": "2", "Area": ["1"], "AreaOther": "", "YearStart": 2555, "YearEnd": 2567, "ClassifiedDimensions": [], "Statistics": "2", "StatisticsBranch": "12"}, {"ListID": 6, "StatisticsName": "ปริมาณการส่งออกรถจักรยานยนต์เฉพาะชิ้นส่วนรถแบบครบชุดสมบูรณ์", "StatisticsCalculation": "7", "Purpose": "เป็นชุดข้อมูลที่ใช้ในโครงการ DI", "Frequency": ["1", "3"], "Urgency": "2", "Area": ["1"], "AreaOther": "", "YearStart": 2555, "YearEnd": 2567, "ClassifiedDimensions": [], "Statistics": "2", "StatisticsBranch": "12"}]}, {"TableID": 2, "SourceTableName": "สถิติปริมาณการผลิตรถยนต์ในประเทศ", "SourceTableUrl": "https://data.thaiauto.or.th/auto/auto-stat/auto-stat-sale-2/stat-internal-auto-importexport.html", "SourceMinistry": "MIN18", "SourceDepartment": "DEP242", "SourceDataOwner": true, "SourceTableStyle": "1", "SourceTableType": "2", "SourceTableTypeFromUrl": "2", "SourceTableTypeFromUrlPdfPageNo": "", "SourceTableTypeFromUrlExcelSheet": "-", "SourceTableFiles": [], "StatisticsList": [{"ListID": 1, "StatisticsName": "มูลค่าการนำเข้ารถยนต์", "StatisticsCalculation": "8", "Purpose": "เป็นชุดข้อมูลที่ใช้ในโครงการ DI", "Frequency": ["3"], "Urgency": "2", "Area": ["1"], "AreaOther": "", "YearStart": 2559, "YearEnd": 2567, "ClassifiedDimensions": [], "Statistics": "2", "StatisticsBranch": "12"}, {"ListID": 2, "StatisticsName": "มูลค่าการนำเข้ารถยนต์นั่ง", "StatisticsCalculation": "8", "Purpose": "เป็นชุดข้อมูลที่ใช้ในโครงการ DI", "Frequency": ["3"], "Urgency": "2", "Area": ["1"], "AreaOther": "", "YearStart": 2559, "YearEnd": 2567, "ClassifiedDimensions": [], "Statistics": "2", "StatisticsBranch": "12"}, {"ListID": 3, "StatisticsName": "มูลค่าการนำเข้ารถบรรทุกและรถโดยสาร", "StatisticsCalculation": "8", "Purpose": "เป็นชุดข้อมูลที่ใช้ในโครงการ DI", "Frequency": ["3"], "Urgency": "2", "Area": ["1"], "AreaOther": "", "YearStart": 2559, "YearEnd": 2567, "ClassifiedDimension ...

# %%
req_data
# Out:
# {'NsoDepartment': '9',
#  'StatisticsName': 'จำนวนเลขหมายโทรศัพท์ประจำที่และโทรศัพท์เคลื่อนที่จัดสรรสะสม',
#  'StatisticsTable': [{'TableID': 1,
#    'SourceTableName': 'จำนวนเลขหมายโทรศัพท์ประจำที่จัดสรรสะสม ประจำปี',
#    'SourceTableUrl': 'https://numbering.nbtc.go.th/FixedExistingNumber/549.aspx',
#    'SourceMinistry': 'MIN8',
#    'SourceDepartment': None,
#    'SourceDataOwner': True,
#    'SourceTableStyle': '1',
#    'SourceTableType': '1',
#    'SourceTableTypeFromUrl': '6',
#    'SourceTableTypeFromUrlPdfPageNo': '',
#    'SourceTableTypeFromUrlExcelSheet': '',
#    'SourceTableFiles': [],
#    'StatisticsList': [{'ListID': 1,
#      'StatisticsName': 'จำนวนเลขหมายโทรศัพท์ประจำที่จัดสรรสะสมของผู้ให้บริการ AMX',
#      'StatisticsCalculation': '1',
#      'Purpose': 'เป็นชุดข้อมูลที่ใช้ในโครงการ DI',
#      'Frequency': ['1'],
#      'Urgency': '2',
#      'Area': ['1'],
#      'AreaOther': '',
#      'YearStart': 2556,
#      'YearEnd': 2566,
#      'ClassifiedDimensions': [{'ClassifiedDimensionID': 1,
#        'Value': 'รหัสนำหน้าหมายเลขโทรศัพท์',
#        'value': None}],
#      'Statistics': '2',
#      'StatisticsBranch': '16'},
#     {'ListID': 2,
#      'StatisticsName': 'จำนวนเลขหมายโทรศัพท์ประจำที่จัดสรรสะสมของผู้ให้บริการ AWN',
#      'StatisticsCalculation': '1',
#      'Purpose': 'เป็นชุดข้อมูลที่ใช้ในโครงการ DI',
#      'Frequency': ['1'],
#      'Urgency': '2',
#      'Area': ['1'],
#      'AreaOther': '',
#      'YearStart': 2556,
#      'YearEnd': 2566,
#      'ClassifiedDimensions': [{'ClassifiedDimensionID': 1,
#        'Value': 'รหัสนำหน้าหมายเลขโทรศัพท์',
#        'value': None}],
#      'Statistics': '2',
#      'StatisticsBranch': '16'},
#     {'ListID': 3,
#      'StatisticsName': 'จำนวนเลขหมายโทรศัพท์ประจำที่จัดสรรสะสมของผู้ให้บริการ 3BB',
#      'StatisticsCalculation': '1',
#      'Purpose': 'เป็นชุดข้อมูลที่ใช้ในโครงการ DI',
#      'Frequency': ['1'],
#      'Urgency': '2',
#      'Area': ['1'],
#      'AreaOther': '',
#      'YearStart': 2556,
#      'YearEnd': 2566,
#      'ClassifiedDimensions': [{'ClassifiedDimensionID': 1,
#        'Value': 'รหัสนำหน้าหมายเลขโทรศัพท์',
#        'value': None}],
#      'Statistics': '2',
#      'StatisticsBranch': '16'},
#     {'ListID': 4,
#      'StatisticsName': 'จำนวนเลขหมายโทรศัพท์ประจำที่จัดสรรสะสมของผู้ให้บริการ DTN',
#      'StatisticsCalculation': '1',
#      'Purpose': 'เป็นชุดข้อมูลที่ใช้ในโครงการ DI',
#      'Frequency': ['1'],
#      'Urgency': '2',
#      'Area': ['1'],
#      'AreaOther': '',
#      'YearStart': 2556,
#      'YearEnd': 2566,
#      'ClassifiedDimensions': [{'ClassifiedDimensionID': 1,
#        'Value': 'รหัสนำหน้าหมายเลขโทรศัพท์',
#        'value': None}],
#      'Statistics': '2',
#      'StatisticsBranch': '16'},
#     {'ListID': 5,
#      'StatisticsName': 'จำนวนเลขหมายโทรศัพท์ประจำที่จัดสรรสะสมของผู้ให้บริการ OTW',
#      'StatisticsCalculation': '1',
#      'Purpose': 'เป็นชุดข้อมูลที่ใช้ในโครงการ DI',
#      'Frequency': ['1'],
#      'Urgency': '2',
#      'Area': ['1'],
#      'AreaOther': '',
#      'YearStart': 2556,
#      'YearEnd': 2566,
#      'ClassifiedDimensions': [{'ClassifiedDimensionID': 1,
#        'Value': 'รหัสนำหน้าหมายเลขโทรศัพท์',
#        'value': None}],
#      'Statistics': '2',
#      'StatisticsBranch': '16'},
#     {'ListID': 6,
#      'StatisticsName': 'จำนวนเลขหมายโทรศัพท์ประจำที่จัดสรรสะสมของผู้ให้บริการ TICC',
#      'StatisticsCalculation': '1',
#      'Purpose': 'เป็นชุดข้อมูลที่ใช้ในโครงการ DI',
#      'Frequency': ['1'],
#      'Urgency': '2',
#      'Area': ['1'],
#      'AreaOther': '',
#      'YearStart': 2556,
#      'YearEnd': 2566,
#      'ClassifiedDimensions': [{'ClassifiedDimensionID': 1,
#        'Value': 'รหัสนำหน้าหมายเลขโทรศัพท์',
#        'value': None}],
#      'Statistics': '2',
#      'StatisticsBranch': '16'},
#     {'ListID': 7,
#      'StatisticsName': 'จำนวนเลขหมายโทรศัพท์ประจำที่จัดสรรสะสมของผู้ให้บริการ NT',
#      'StatisticsCalculation': '1',
#      'Purpose': 'เป็นชุดข้อมูลที่ใช้ในโครงการ DI',
#      'Frequency': ['1'],
#      'Urgency': '2',
#      'Area': ['1'],
#      'AreaOther': '',
#      'YearStart': 2556,
#      'YearEnd': 2566,
#      'ClassifiedDimensions': [{'ClassifiedDimensionID': 1,
#        'Value': 'รหัสนำหน้าหมายเลขโทรศัพท์',
#        'value': None}],
#      'Statistics': '2',
#      'StatisticsBranch': '16'},
#     {'ListID': 8,
#      'StatisticsName': 'จำนวนเลขหมายโทรศัพท์ประจำที่จัดสรรสะสม',
#      'StatisticsCalculation': '1',
#      'Purpose': 'เป็นชุดข้อมูลที่ใช้ในโครงการ DI',
#      'Frequency': ['1'],
#      'Urgency': '2',
#      'Area': ['1'],
#      'AreaOther': '',
#      'YearStart': 2556,
#      'YearEnd': 2566,
#      'ClassifiedDimensions': [{'ClassifiedDimensionID': 1,
#        'Value': 'รหัสนำหน้าหมายเลขโทรศัพท์',
#        'value': None}],
#      'Statistics': '2',
#      'StatisticsBranch': '16'}]},
#   {'TableID': 2,
#    'SourceTableName': 'จำนวนเลขหมายโทรศัพท์ประจำที่จัดสรรสะสม',
#    'SourceTableUrl': 'https://numbering.nbtc.go.th/FixedExistingNumber/549.aspx',
#    'SourceMinistry': 'MIN8',
#    'SourceDepartment': 'DEP199',
#    'SourceDataOwner': True,
#    'SourceTableStyle': '1',
#    'SourceTableType': '1',
#    'SourceTableTypeFromUrl': '6',
#    'SourceTableTypeFromUrlPdfPageNo': '',
#    'SourceTableTypeFromUrlExcelSheet': '',
#    'SourceTableFiles': [],
#    'StatisticsList': [{'ListID': 1,
#      'StatisticsName': 'จำนวนเลขหมายโทรศัพท์ประจำที่จัดสรรสะสมคงเหลือ',
#      'StatisticsCalculation': '1',
#      'Purpose': 'เป็นชุดข้อมูลที่ใช้ในโครงการ DI',
#      'Frequency': ['1'],
#      'Urgency': '2',
#      'Area': ['1'],
#      'AreaOther': '',
#      'YearStart': 2556,
#      'YearEnd': 2566,
#      'ClassifiedDimensions': [{'ClassifiedDimensionID': 1,
#        'Value': 'รหัสนำหน้าหมายเลขโทรศัพท์',
#        'value': None}],
#      'Statistics': '2',
#      'StatisticsBranch': '16'}]},
#   {'TableID': 3,
#    'SourceTableName': 'จำนวนเลขหมายโทรศัพท์เคลื่อนที่จัดสรรสะสม',
#    'SourceTableUrl': 'https://numbering.nbtc.go.th/FixedExistingNumber/558.aspx',
#    'SourceMinistry': 'MIN8',
#    'SourceDepartment': 'DEP199',
#    'SourceDataOwner': True,
#    'SourceTableStyle': '1',
#    'SourceTableType': '1',
#    'SourceTableTypeFromUrl': '6',
#    'SourceTableTypeFromUrlPdfPageNo': '',
#    'SourceTableTypeFromUrlExcelSheet': '',
#    'SourceTableFiles': [],
#    'StatisticsList': [{'ListID': 1,
#      'StatisticsName': 'จำนวนเลขหมายโทรศัพท์เคลื่อนที่จัดสรรสะสม บริษัท AIS',
#      'StatisticsCalculation': '1',
#      'Purpose': 'เป็นชุดข้อมูลที่ใช้ในโครงการ DI',
#      'Frequency': ['1'],
#      'Urgency': '2',
#      'Area': ['1'],
#      'AreaOther': '',
#      'YearStart': 2564,
#      'YearEnd': 2566,
#      'ClassifiedDimensions': [],
#      'Statistics': '2',
#      'StatisticsBranch': '16'},
#     {'ListID': 2,
#      'StatisticsName': 'จำนวนเลขหมายโทรศัพท์เคลื่อนที่จัดสรรสะสม กลุ่มบริษัท DTAC',
#      'StatisticsCalculation': '1',
#      'Purpose': 'เป็นชุดข้อมูลที่ใช้ในโครงการ DI',
#      'Frequency': ['1'],
#      'Urgency': '2',
#      'Area': ['1'],
#      'AreaOther': '',
#      'YearStart': 2564,
#      'YearEnd': 2566,
#      'ClassifiedDimensions': [],
#      'Statistics': '2',
#      'StatisticsBranch': '16'},
#     {'ListID': 3,
#      'StatisticsName': 'จำนวนเลขหมายโทรศัพท์เคลื่อนที่จัดสรรสะสม กลุ่มบริษัท TRUE',
#      'StatisticsCalculation': '1',
#      'Purpose': 'เป็นชุดข้อมูลที่ใช้ในโครงการ DI',
#      'Frequency': ['2'],
#      'Urgency': '2',
#      'Area': ['1'],
#      'AreaOther': '',
#      'YearStart': 2564,
#      'YearEnd': 2566,
#      'ClassifiedDimensions': [],
#      'Statistics': '2',
#      'StatisticsBranch': '16'},
#     {'ListID': 4,
#      'StatisticsName': 'จำนวนเลขหมายโทรศัพท์เคลื่อนที่จัดสรรสะสม บริษัท Aces',
#      'StatisticsCalculation': '1',
#      'Purpose': 'เป็นชุดข้อมูลที่ใช้ในโครงการ DI',
#      'Frequency': ['2'],
#      'Urgency': '2',
#      'Area': ['1'],
#      'AreaOther': '',
#      'YearStart': 2564,
#      'YearEnd': 2566,
#      'ClassifiedDimensions': [],
#      'Statistics': '2',
#      'StatisticsBranch': '16'},
#     {'ListID': 5,
#      'StatisticsName': 'จำนวนเลขหมายโทรศัพท์เคลื่อนที่จัดสรรสะสม กลุ่มบริษัท ผู้ให้บริการ MVNO',
#      'StatisticsCalculation': '1',
#      'Purpose': 'เป็นชุดข้อมูลที่ใช้ในโครงการ DI',
#      'Frequency': ['2'],
#      'Urgency': '2',
#      'Area': ['1'],
#      'AreaOther': '',
#      'YearStart': 2564,
#      'YearEnd': 2566,
#      'ClassifiedDimensions': [],
#      'Statistics': '2',
#      'StatisticsBranch': '16'},
#     {'ListID': 6,
#      'StatisticsName': 'จำนวนเลขหมายโทรศัพท์เคลื่อนที่จัดสรรสะสม บริษัท NT',
#      'StatisticsCalculation': '1',
#      'Purpose': 'เป็นชุดข้อมูลที่ใช้ในโครงการ DI',
#      'Frequency': ['2'],
#      'Urgency': '2',
#      'Area': ['1'],
#      'AreaOther': '',
#      'YearStart': 2564,
#      'YearEnd': 2566,
#      'ClassifiedDimensions': [],
#      'Statistics': '2',
#      'StatisticsBranch': '16'}]}]}

# %%
DF = 'DF_11DI_AG_RICE_VOL'
version = '1.0'
url = 'https://ns2-staging.nso.go.th/rest/data/TNSO,%s,%s/all?dimensionAtObservation=AllDimensions&format=csvfilewithlabels'%(DF,version)
data = pd.read_csv(url)

# %%
response.json
# Out:
# <bound method Response.json of <Response [200]>>

# %%
data = pd.read_csv(url)

# %%
data
# Out:
#     STRUCTURE                   STRUCTURE_ID                 STRUCTURE_NAME  \
# 0    DATAFLOW  TNSO:DF_11DI_AG_RICE_VOL(1.0)  Volume of Rice Seeds dataflow
# 1    DATAFLOW  TNSO:DF_11DI_AG_RICE_VOL(1.0)  Volume of Rice Seeds dataflow
# 2    DATAFLOW  TNSO:DF_11DI_AG_RICE_VOL(1.0)  Volume of Rice Seeds dataflow
# 3    DATAFLOW  TNSO:DF_11DI_AG_RICE_VOL(1.0)  Volume of Rice Seeds dataflow
# 4    DATAFLOW  TNSO:DF_11DI_AG_RICE_VOL(1.0)  Volume of Rice Seeds dataflow
# ..        ...                            ...                            ...
# 219  DATAFLOW  TNSO:DF_11DI_AG_RICE_VOL(1.0)  Volume of Rice Seeds dataflow
# 220  DATAFLOW  TNSO:DF_11DI_AG_RICE_VOL(1.0)  Volume of Rice Seeds dataflow
# 221  DATAFLOW  TNSO:DF_11DI_AG_RICE_VOL(1.0)  Volume of Rice Seeds dataflow
# 222  DATAFLOW  TNSO:DF_11DI_AG_RICE_VOL(1.0)  Volume of Rice Seeds dataflow
# 223  DATAFLOW  TNSO:DF_11DI_AG_RICE_VOL(1.0)  Volume of Rice Seeds dataflow
#
#     ACTION AG_STAT Agricultural Statistics    COMMOD  \
# 0        I   AG033      Rice seed quantity  100008_3
# 1        I   AG033      Rice seed quantity  100008_3
# 2        I   AG033      Rice seed quantity  100008_3
# 3        I   AG033      Rice seed quantity  100008_3
# 4        I   AG033      Rice seed quantity  100008_3
# ..     ...     ...                     ...       ...
# 219      I   AG033      Rice seed quantity    100001
# 220      I   AG033      Rice seed quantity    100001
# 221      I   AG033      Rice seed quantity    100001
# 222      I   AG033      Rice seed quantity    100001
# 223      I   AG033      Rice seed quantity    100001
#
#                                 Commodity     RICE   Rice  ... UNIT    Unit  \
# 0    Rice is not sensitive to photoperiod  R200114   RD41  ...   TN  Tonnes
# 1    Rice is not sensitive to photoperiod  R200114   RD41  ...   TN  Tonnes
# 2    Rice is not sensitive to photoperiod  R200114   RD41  ...   TN  Tonnes
# 3    Rice is not sensitive to photoperiod  R200114   RD41  ...   TN  Tonnes
# 4    Rice is not sensitive to photoperiod  R200114   RD41  ...   TN  Tonnes
# ..                                    ...      ...    ...  ...  ...     ...
# 219                            mixed rice       _T  Total  ...   TN  Tonnes
# 220                            mixed rice       _T  Total  ...   TN  Tonnes
# 221                            mixed rice       _T  Total  ...   TN  Tonnes
# 222                            mixed rice       _T  Total  ...   TN  Tonnes
# 223                            mixed rice       _T  Total  ...   TN  Tonnes
#
#     FREQ Frequency TIME_PERIOD Time period  OBS_VALUE  Observation Value  \
# 0      A    Annual        2557         NaN   9999.000                NaN
# 1      A    Annual        2558         NaN   2724.480                NaN
# 2      A    Annual        2559         NaN   6684.930                NaN
# 3      A    Annual        2560         NaN   5857.975                NaN
# 4      A    Annual        2561         NaN   6980.675                NaN
# ..   ...       ...         ...         ...        ...                ...
# 219    A    Annual        2560         NaN  72125.550                NaN
# 220    A    Annual        2561         NaN  72943.300                NaN
# 221    A    Annual        2562         NaN  68960.025                NaN
# 222    A    Annual        2563         NaN  64068.125                NaN
# 223    A    Annual        2564         NaN  78776.575                NaN
#
#          SOURCE  Source
# 0    กรมการข้าว     NaN
# 1    กรมการข้าว     NaN
# 2    กรมการข้าว     NaN
# 3    กรมการข้าว     NaN
# 4    กรมการข้าว     NaN
# ..          ...     ...
# 219  กรมการข้าว     NaN
# 220  กรมการข้าว     NaN
# 221  กรมการข้าว     NaN
# 222  กรมการข้าว     NaN
# 223  กรมการข้าว     NaN
#
# [224 rows x 22 columns]

# %%
# break_list = ['จำนวนคนจน และสัดส่วนคนจนจำแนกตามขนาดครัวเรือน','สถิติส่งเสริมการลงทุน','สถาบันยานยนต์','โรงงานอุตสาหกรรมที่เลิกประกอบกิจการ','การจ้างงาน และรายได้ของวิสาหกิจขนาดกลางและขนาดย่อม','นักท่องเที่ยวระหว่างประเทศที่เดินทางเข้าประเทศไทย','การสะสมทุนถาวรขั้นต้นตามสถาบันภาครัฐและเอกชน','รายจ่ายเกี่ยวกับผลิตภัณฑ์มวลรวมภายในประเทศ การวัดปริมาณห่วงโซ่','สถิติสำหรับจัดทำดัชนีอุตสาหกรรม']
# break_list = ['รายงานต้นทุนผลผลิต']
# break_list = ['จำนวนคนจน และสัดส่วนคนจนจำแนกตามขนาดครัวเรือน','สถาบันยานยนต์','การจ้างงาน และรายได้ของวิสาหกิจขนาดกลางและขนาดย่อม','สถิติสำหรับจัดทำดัชนีอุตสาหกรรม','การสะสมทุนถาวรขั้นต้นตามสถาบันภาครัฐและเอกชน']
break_list =[]
# break_list=['ผู้ต้องขังที่ได้รับการปล่อยตัวและกลับมากระทำผิดอีกครั้ง']
req_name = df['ชื่อคำร้องขอ'].unique()
count = 0 
row =0
for x in req_name:
    # print('ชื่อคำร้อง :',x)
    if x in break_list:
        continue
    j=1
    df_req = df.loc[df['ชื่อคำร้องขอ']== x]
    table_name = df_req['ชื่อตารางสถิติแสดงจากแหล่งข้อมูลต้นทาง'].unique()
    table_len = len(table_name)
    temp_table = []
    for y in table_name:
        # print(' ชื่อตารางสถิติ :',y)
        df_table = df_req.loc[df_req['ชื่อตารางสถิติแสดงจากแหล่งข้อมูลต้นทาง']== y]
        df_table = df_table.reset_index(drop=True)
        static_name = df_table['ชื่อรายการสถิติ'].unique()
        temp_static =[]
        i=1
        for z in static_name:
            # print(z)
            df_static = df_table.loc[df_table['ชื่อรายการสถิติ']== z]
            df_static = df_static.reset_index(drop=True)
            # try:
            # print(df_static['No (อ้างอิงภาคผนวก ข)'].values[0])
            frequency_array = []
            area_array = []
            frequency_split = df_static['ความถี่ในการเผยแพร่ข้อมูล'].values[0]
            frequency_split = frequency_split.split('\n')
            for a in frequency_split:
                if a == '':
                    continue
                else:
                    frequency_array.append(frequency['value'].loc[frequency['text']== a[2:].rstrip()].values[0])
            aresplit =df_static['พื้นที่\n(ใส่ในคำร้อง)'].values[0]
            aresplit = aresplit.split('\n')
            dimension = []
            for b in aresplit:
                area_array.append(areatype(str(b[2:])))
            AreaOther = ""
            if '8' in area_array:
                area_array.remove('8')
            if '7' in area_array:
                AreaOther = df_static['นอกเหนือจาก ทั่วราช ภาค จังหวัด เขตการปกครอง อำเภอ ตำบล'].values[0]
                AreaOther = AreaOther[2:]
                # if type(AreaOther) == float:
                #      AreaOther = ""
                # else:
                #     AreaOther = AreaOther[2:]
            dimensionslit = df_table['การจัดจำแนก'].values[0]
            dimensionslit = dimensionslit.split('\n')
            dimensionarray = []
            if '- ไม่มีการจัดจำแนก' in dimensionslit:
                dimensionarray = []
            else:
                k=1
                for c in dimensionslit:
                    if c == '':
                        continue
                    else:
                        dimension = {
                        "ClassifiedDimensionID": k,
                        "Value": c[2:],
                        "value": None
                    }
                    k=k+1
                    dimensionarray.append(dimension)
            body_static = {
                        "ListID": i,
                        "StatisticsName": z,
                        "StatisticsCalculation": (statistics_calculation['value'].loc[statistics_calculation['text']==df_static['การคำนวณค่าสถิติ'][0]].values[0]),
                        "Purpose": df_static['วัตถุประสงค์การใช้งาน'][0],
                        "Frequency": frequency_array,
                        "Urgency": urgency['value'].loc[urgency['text']== df_static['ความเร่งด่วนการนำมาใช้งาน'][0]].values[0],
                        "Area": area_array,
                        "AreaOther": AreaOther[2:],
                        "YearStart": df_static['ปีเริ่มต้น'][0],
                        "YearEnd": df_static['ปีสิ้นสุด'][0],
                        "ClassifiedDimensions": dimensionarray,
                        "Statistics": statistics['value'].loc[statistics['text']== df_static['สถิติ'][0]].values[0],
                        "StatisticsBranch": str(int(df_static['สาขา'][0][:2]))
                    }
            temp_static.append(body_static)
            # except Exception as error:
                # handle the exception
            # print(df_static['No (อ้างอิงภาคผนวก ข)'])
            # print("An exception occurred:", error)
            i=i+1
        # break
        page = ""
        sheet = ""
        if df_table['รูปแบบของตารางสถิติจาก URL แหล่งข้อมูลต้นทาง'].values[0] == 'XLS' or df_table['รูปแบบของตารางสถิติจาก URL แหล่งข้อมูลต้นทาง'].values[0] == 'XLSX' or df_table['รูปแบบของตารางสถิติจาก URL แหล่งข้อมูลต้นทาง'].values[0] == 'xls':
            df_table['รูปแบบของตารางสถิติจาก URL แหล่งข้อมูลต้นทาง'].values[0] = 'EXCEL'
        if df_table['รูปแบบของตารางสถิติจาก URL แหล่งข้อมูลต้นทาง'].values[0] == 'PDF':
            page = df_table['ระบุหน้า'].values[0]
        elif df_table['รูปแบบของตารางสถิติจาก URL แหล่งข้อมูลต้นทาง'].values[0] == 'EXCEL':
            sheet = df_table['ระบุหน้า'].values[0]
            sheet = str(sheet).replace('\n', ' ')
        body_table = {
            "TableID": j,
            "SourceTableName": y,
            "SourceTableUrl": df_table['URL ของแหล่งข้อมูลต้นทาง'].values[0],
            "SourceMinistry": MIN_ID(df_table['กระทรวง'].values[0]),
            "SourceDepartment": DEP_ID(df_table['กรม'].values[0]),
            "SourceDataOwner": data_onwer(df_table['หน่วยงานนี้เป็นผู้ผลิตข้อมูลสถิติ (Data Owner) ใช่หรือไม่'].values[0]),
            "SourceTableStyle": source_table_style['value'].loc[source_table_style['text']== df_table['ลักษณะของตารางสถิติ'][0]].values[0],
            "SourceTableType": source_table_type['value'].loc[source_table_type['text']== df_table['รูปแบบการใช้บริการของไฟล์ต้นทาง'][0]].values[0],
            "SourceTableTypeFromUrl": source_table_type_from_url['value'].loc[source_table_type_from_url['text'] == df_table['รูปแบบของตารางสถิติจาก URL แหล่งข้อมูลต้นทาง'].values[0]].values[0],
            "SourceTableTypeFromUrlPdfPageNo": page,
            "SourceTableTypeFromUrlExcelSheet": sheet,
            "SourceTableFiles": [],
            "StatisticsList": temp_static
            }
        temp_table.append(body_table)
        j=j+1
    #print(table_len)
    count = count + len(df_req)
    ##print(row,"ชื่อคำร้อง :",x,"คำร้อง :",len(df_req),"จำนวนตาราง :",table_len)
    # if row == 0:
    #     break
    row = row+1
    req_data = { "NsoDepartment": nso_department['value'].loc[nso_department['text']== df_req['ชื่อหน่วยงานของผู้ร้องขอ'].values[0]].values[0],
    "StatisticsName": df_req['ชื่อคำร้องขอ'].values[0],
    "StatisticsTable": temp_table
    }
    try:
        url = "http://docker.greencluster.co.th:8005/api/v1/Authentication/Login/LoginByEmail"
        headers = {
            "accept": "application/json",
            "Content-Type": "application/json"
        }
        data = {
        "email": "tanat.time@gmail.com",
        "password": "123456",
        "mastSystemKey": "SYS1"
        }

        response = requests.post(url, headers=headers, json=data)

        # print(response.status_code)
        # print(response.json())
        token = response.json()['ACCESS_TOKEN']
        # print(token)


        url = "http://docker.greencluster.co.th:8001/api/v1/StatisticsRequest/Request/Submit"

        headers = {
            "accept": "*/*",
            "UserAuthenticatedToken": token,
            "Content-Type": "application/json"
        }


        str_req_data = str(req_data).replace("'", '"')
        json_req_data = str_req_data.replace("True", "true")
        json_req_data = json_req_data.replace("None", "null")
        try:
            data_json = json.loads(json_req_data)
            # print(data_json)
        except json.JSONDecodeError as e:
            print(f"JSONDecodeError: {e.msg} at line {e.lineno} column {e.colno} (char {e.pos})")
        response = requests.post(url, headers=headers, json=data_json)
        print('success ชื่อคำร้อง :',x)
    except Exception as error:
        print('error ชื่อคำร้อง :',x)
        print("An exception occurred:", error)
        
print("final count :",count)
print("final row :",row)
# Out:
# success ชื่อคำร้อง : ปริมาณเมล็ดพันธุ์ข้าว
# final count : 1
# final row : 1

# %%
a =0
